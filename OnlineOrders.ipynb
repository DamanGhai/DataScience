# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
online_orders = pd.read_csv('onlinefoods.csv')
online_orders.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
online_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         388 non-null    int64
#  1   Gender                      388 non-null    object
#  2   Marital Status              388 non-null    object
#  3   Occupation                  388 non-null    object
#  4   Monthly Income              388 non-null    object
#  5   Educational Qualifications  388 non-null    object
#  6   Family size                 388 non-null    int64
#  7   latitude                    388 non-null    float64
#  8   longitude                   388 non-null    float64
#  9   Pin code                    388 non-null    int64
#  10  Output                      388 non-null    object
#  11  Feedback                    388 non-null    object
#  12  Unnamed: 12                 388 non-null    object
# ...

# %%
online_orders['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
online_orders= pd.get_dummies(online_orders, columns=['Gender'])

# %%
online_orders.head()
# Out:
#    Age Marital Status Occupation  Monthly Income Educational Qualifications  \
# 0   20         Single    Student       No Income              Post Graduate
# 1   24         Single    Student  Below Rs.10000                   Graduate
# 2   22         Single    Student  Below Rs.10000              Post Graduate
# 3   22         Single    Student       No Income                   Graduate
# 4   22         Single    Student  Below Rs.10000              Post Graduate
#
#    Family size  latitude  longitude  Pin code Output   Feedback Unnamed: 12  \
# 0            4   12.9766    77.5993    560001    Yes   Positive         Yes
# 1            3   12.9770    77.5773    560009    Yes   Positive         Yes
# 2            3   12.9551    77.6593    560017    Yes  Negative          Yes
# 3            6   12.9473    77.5616    560019    Yes   Positive         Yes
# 4            4   12.9850    77.5533    560010    Yes   Positive         Yes
#
#    Gender_Female  Gender_Male
# ...

# %%
online_orders.isnull().sum()
# Out:
# Age                           0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# Unnamed: 12                   0
# Gender_Female                 0
# Gender_Male                   0
# dtype: int64

# %%
online_orders['Occupation'].unique()
# Out:
# array(['Student', 'Employee', 'Self Employeed', 'House wife'],
#       dtype=object)

# %%
online_orders['Educational Qualifications'].unique()
# Out:
# array(['Post Graduate', 'Graduate', 'Ph.D', 'Uneducated', 'School'],
#       dtype=object)

# %%
online_orders['Marital Status'].unique()
# Out:
# array(['Single', 'Married', 'Prefer not to say'], dtype=object)

# %%
online_orders = pd.get_dummies(online_orders, columns=['Educational Qualifications','Occupation','Marital Status'])

# %%
online_orders.head()
# Out:
#    Age  Monthly Income  Family size  latitude  longitude  Pin code Output  \
# 0   20       No Income            4   12.9766    77.5993    560001    Yes
# 1   24  Below Rs.10000            3   12.9770    77.5773    560009    Yes
# 2   22  Below Rs.10000            3   12.9551    77.6593    560017    Yes
# 3   22       No Income            6   12.9473    77.5616    560019    Yes
# 4   22  Below Rs.10000            4   12.9850    77.5533    560010    Yes
#
#     Feedback Unnamed: 12  Gender_Female  ...  \
# 0   Positive         Yes              1  ...
# 1   Positive         Yes              1  ...
# 2  Negative          Yes              0  ...
# 3   Positive         Yes              1  ...
# 4   Positive         Yes              0  ...
#
#    Educational Qualifications_Post Graduate  \
# 0                                         1
# 1                                         0
# 2                                         1
# 3                                         0
# ...

# %%
online_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 23 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Age                                       388 non-null    int64
#  1   Monthly Income                            388 non-null    object
#  2   Family size                               388 non-null    int64
#  3   latitude                                  388 non-null    float64
#  4   longitude                                 388 non-null    float64
#  5   Pin code                                  388 non-null    int64
#  6   Output                                    388 non-null    object
#  7   Feedback                                  388 non-null    object
#  8   Unnamed: 12                               388 non-null    object
#  9   Gender_Female                             388 non-null    uint8
# ...

# %%
online_orders['Monthly Income'].unique()
# Out:
# array(['No Income', 'Below Rs.10000', 'More than 50000', '10001 to 25000',
#        '25001 to 50000'], dtype=object)

# %%
online_orders['Monthly Income'] = online_orders['Monthly Income'].map({'No Income':0,'Below Rs.10000':9000,'More than 50000':51000,'10001 to 25000':15000})

# %%
online_orders.head()
# Out:
#    Age  Monthly Income  Family size  latitude  longitude  Pin code Output  \
# 0   20             0.0            4   12.9766    77.5993    560001    Yes
# 1   24          9000.0            3   12.9770    77.5773    560009    Yes
# 2   22          9000.0            3   12.9551    77.6593    560017    Yes
# 3   22             0.0            6   12.9473    77.5616    560019    Yes
# 4   22          9000.0            4   12.9850    77.5533    560010    Yes
#
#     Feedback Unnamed: 12  Gender_Female  ...  \
# 0   Positive         Yes              1  ...
# 1   Positive         Yes              1  ...
# 2  Negative          Yes              0  ...
# 3   Positive         Yes              1  ...
# 4   Positive         Yes              0  ...
#
#    Educational Qualifications_Post Graduate  \
# 0                                         1
# 1                                         0
# 2                                         1
# 3                                         0
# ...

# %%
online_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 23 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Age                                       388 non-null    int64
#  1   Monthly Income                            319 non-null    float64
#  2   Family size                               388 non-null    int64
#  3   latitude                                  388 non-null    float64
#  4   longitude                                 388 non-null    float64
#  5   Pin code                                  388 non-null    int64
#  6   Output                                    388 non-null    object
#  7   Feedback                                  388 non-null    object
#  8   Unnamed: 12                               388 non-null    object
#  9   Gender_Female                             388 non-null    uint8
# ...

# %%
online_orders['Output'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
online_orders['Output'].value_counts()
# Out:
# Yes    301
# No      87
# Name: Output, dtype: int64

# %%
online_orders['Feedback'].unique()
# Out:
# array(['Positive', 'Negative '], dtype=object)

# %%
online_orders= pd.get_dummies(online_orders, columns=['Feedback'])

# %%
online_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 24 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Age                                       388 non-null    int64
#  1   Monthly Income                            319 non-null    float64
#  2   Family size                               388 non-null    int64
#  3   latitude                                  388 non-null    float64
#  4   longitude                                 388 non-null    float64
#  5   Pin code                                  388 non-null    int64
#  6   Output                                    388 non-null    object
#  7   Unnamed: 12                               388 non-null    object
#  8   Gender_Female                             388 non-null    uint8
#  9   Gender_Male                               388 non-null    uint8
# ...

# %%
online_orders.drop(columns=['Unnamed: 12'], axis =1 ,inplace = True)

# %%
online_orders.head()
# Out:
#    Age  Monthly Income  Family size  latitude  longitude  Pin code Output  \
# 0   20             0.0            4   12.9766    77.5993    560001    Yes
# 1   24          9000.0            3   12.9770    77.5773    560009    Yes
# 2   22          9000.0            3   12.9551    77.6593    560017    Yes
# 3   22             0.0            6   12.9473    77.5616    560019    Yes
# 4   22          9000.0            4   12.9850    77.5533    560010    Yes
#
#    Gender_Female  Gender_Male  Educational Qualifications_Graduate  ...  \
# 0              1            0                                    0  ...
# 1              1            0                                    1  ...
# 2              0            1                                    0  ...
# 3              1            0                                    1  ...
# 4              0            1                                    0  ...
#
#    Educational Qualifications_Uneducated  Occupation_Employee  \
# ...

# %%
online_orders['Output']=online_orders['Output'].map({'Yes':1,'No':0})

# %%
online_orders.head()
# Out:
#    Age  Monthly Income  Family size  latitude  longitude  Pin code  Output  \
# 0   20             0.0            4   12.9766    77.5993    560001       1
# 1   24          9000.0            3   12.9770    77.5773    560009       1
# 2   22          9000.0            3   12.9551    77.6593    560017       1
# 3   22             0.0            6   12.9473    77.5616    560019       1
# 4   22          9000.0            4   12.9850    77.5533    560010       1
#
#    Gender_Female  Gender_Male  Educational Qualifications_Graduate  ...  \
# 0              1            0                                    0  ...
# 1              1            0                                    1  ...
# 2              0            1                                    0  ...
# 3              1            0                                    1  ...
# 4              0            1                                    0  ...
#
#    Educational Qualifications_Uneducated  Occupation_Employee  \
# ...

# %%
corrd = online_orders.corr()
print(corrd['Output'].sort_values(ascending=False))
# Out:
# Output                                      1.000000
# Feedback_Positive                           0.592609
# Occupation_Student                          0.290040
# Marital Status_Single                       0.282010
# Educational Qualifications_Post Graduate    0.149296
# longitude                                   0.045265
# Gender_Male                                 0.034701
# Educational Qualifications_School           0.024655
# Occupation_House wife                       0.000741
# Pin code                                   -0.019929
# Gender_Female                              -0.034701
# Family size                                -0.043780
# Educational Qualifications_Uneducated      -0.047595
# Educational Qualifications_Ph.D            -0.048223
# Marital Status_Prefer not to say           -0.118124
# Educational Qualifications_Graduate        -0.127937
# Occupation_Self Employeed                  -0.140894
# latitude                                   -0.159963
# ...

# %%
online_orders.describe()
# Out:
#               Age  Monthly Income  Family size    latitude   longitude  \
# count  388.000000      319.000000   388.000000  388.000000  388.000000
# mean    24.628866    12733.542320     3.280928   12.972058   77.600160
# std      2.975593    19561.895888     1.351025    0.044489    0.051354
# min     18.000000        0.000000     1.000000   12.865200   77.484200
# 25%     23.000000        0.000000     2.000000   12.936900   77.565275
# 50%     24.000000        0.000000     3.000000   12.977000   77.592100
# 75%     26.000000    15000.000000     4.000000   12.997025   77.630900
# max     33.000000    51000.000000     6.000000   13.102000   77.758200
#
#             Pin code      Output  Gender_Female  Gender_Male  \
# count     388.000000  388.000000     388.000000   388.000000
# mean   560040.113402    0.775773       0.427835     0.572165
# std        31.399609    0.417611       0.495404     0.495404
# min    560001.000000    0.000000       0.000000     0.000000
# ...

# %%
sns.displot(online_orders['Monthly Income'])

# %%
online_orders[online_orders['Monthly Income'].isnull()]
# Out:
#      Age  Monthly Income  Family size  latitude  longitude  Pin code  Output  \
# 16    28             NaN            2   12.9783    77.6408    560038       1
# 62    23             NaN            1   13.0158    77.5390    560096       1
# 75    24             NaN            3   13.1020    77.5864    560064       1
# 90    27             NaN            5   13.0289    77.5400    560022       0
# 98    26             NaN            5   12.9579    77.6309    560007       0
# ..   ...             ...          ...       ...        ...       ...     ...
# 361   24             NaN            3   13.0103    77.5796    560080       0
# 364   29             NaN            3   13.0641    77.5931    560092       0
# 367   27             NaN            2   12.8845    77.6036    560076       1
# 371   28             NaN            3   12.9369    77.6407    560095       1
# 378   23             NaN            2   12.9847    77.5491    560100       1
#
# ...

# %%
online_orders['Monthly Income']= online_orders['Monthly Income'].fillna(value='0')

# %%
online_orders[online_orders['Monthly Income'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Monthly Income, Family size, latitude, longitude, Pin code, Output, Gender_Female, Gender_Male, Educational Qualifications_Graduate, Educational Qualifications_Ph.D, Educational Qualifications_Post Graduate, Educational Qualifications_School, Educational Qualifications_Uneducated, Occupation_Employee, Occupation_House wife, Occupation_Self Employeed, Occupation_Student, Marital Status_Married, Marital Status_Prefer not to say, Marital Status_Single, Feedback_Negative , Feedback_Positive]
# Index: []
#
# [0 rows x 23 columns]

# %%
X =  online_orders.drop(columns='Output', axis=1)
Y = online_orders['Output']

# %%
X.shape
# Out:
# (388, 22)

# %%
Y.shape
# Out:
# (388,)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X,Y, test_size=0.2,random_state=5)

# %%
ytrain.head()
# Out:
# 185    1
# 259    0
# 88     0
# 248    0
# 12     1
# Name: Output, dtype: int64

# %%
xtrain.head()
# Out:
#      Age Monthly Income  Family size  latitude  longitude  Pin code  \
# 185   28        51000.0            1   12.9925    77.5633    560021
# 259   28              0            6   12.9967    77.7582    560067
# 88    25            0.0            5   12.9770    77.5773    560009
# 248   31         9000.0            1   12.9866    77.4904    560091
# 12    23            0.0            5   12.8988    77.5764    560078
#
#      Gender_Female  Gender_Male  Educational Qualifications_Graduate  \
# 185              0            1                                    0
# 259              1            0                                    0
# 88               0            1                                    0
# 248              0            1                                    1
# 12               0            1                                    0
#
#      Educational Qualifications_Ph.D  ...  \
# 185                                0  ...
# 259                                0  ...
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier()

# %%
pred = rf.predict(xtest)
from sklearn.metrics import accuracy_score
print(accuracy_score(pred, ytest)*100)
# Out:
# 91.02564102564102
